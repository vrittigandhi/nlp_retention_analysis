# %% [markdown]
# # Part 2, Zero Shot Sentiments

# %%
# !pip install ktrain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ktrain
#   Downloading ktrain-0.31.2.tar.gz (25.3 MB)
#      |████████████████████████████████| 25.3 MB 39 kB/s  eta 0:00:014.6 MB/s eta 0:00:05          | 11.5 MB 4.6 MB/s eta 0:00:04        | 18.4 MB 4.6 MB/s eta 0:00:02��███████████████▊| 25.1 MB 4.6 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn==0.24.2 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from ktrain) (0.24.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from ktrain) (3.4.3)
# Requirement already satisfied: pandas>=1.0.1 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from ktrain) (1.3.3)
# Collecting fastprogress>=0.1.21
#   Downloading fastprogress-1.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: requests in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from ktrain) (2.26.0)
# Requirement already satisfied: joblib in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from ktrain) (1.0.1)
# Requirement already satisfied: packaging in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from ktrain) (21.0)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 92.9 MB/s eta 0:00:01
# Collecting jieba
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      |████████████████████████████████| 19.2 MB 97.1 MB/s eta 0:00:01             | 5.3 MB 97.1 MB/s eta 0:00:01��████████████████████▋          | 12.9 MB 97.1 MB/s eta 0:00:01
# Collecting cchardet
#   Downloading cchardet-2.1.7-cp39-cp39-manylinux2010_x86_64.whl (265 kB)
#      |████████████████████████████████| 265 kB 120.6 MB/s eta 0:00:01
# Collecting chardet
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 115.2 MB/s eta 0:00:01
# Collecting syntok==1.3.3
#   Downloading syntok-1.3.3-py3-none-any.whl (22 kB)
# Collecting transformers==4.10.3
#   Downloading transformers-4.10.3-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 120.0 MB/s eta 0:00:01  |███████████▉                    | 1.0 MB 120.0 MB/s eta 0:00:01
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 102.0 MB/s eta 0:00:01
# Collecting keras_bert>=0.86.0
#   Downloading keras-bert-0.89.0.tar.gz (25 kB)
# Collecting whoosh
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 106.4 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.19.1 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from scikit-learn==0.24.2->ktrain) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from scikit-learn==0.24.2->ktrain) (2.2.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/vritti/.local/lib/python3.9/site-packages (from scikit-learn==0.24.2->ktrain) (1.22.4)
# Requirement already satisfied: regex in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from syntok==1.3.3->ktrain) (2021.8.3)
# Requirement already satisfied: huggingface-hub>=0.0.12 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from transformers==4.10.3->ktrain) (0.1.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from transformers==4.10.3->ktrain) (0.10.3)
# Requirement already satisfied: filelock in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from transformers==4.10.3->ktrain) (3.4.0)
# Requirement already satisfied: tqdm>=4.27 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from transformers==4.10.3->ktrain) (4.62.3)
# Requirement already satisfied: sacremoses in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from transformers==4.10.3->ktrain) (0.0.46)
# Requirement already satisfied: pyyaml>=5.1 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from transformers==4.10.3->ktrain) (5.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from huggingface-hub>=0.0.12->transformers==4.10.3->ktrain) (3.7.4.3)
# Collecting keras-transformer==0.40.0
#   Downloading keras-transformer-0.40.0.tar.gz (9.7 kB)
# Collecting keras-pos-embd==0.13.0
#   Downloading keras-pos-embd-0.13.0.tar.gz (5.6 kB)
# Collecting keras-multi-head==0.29.0
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
# Collecting keras-layer-normalization==0.16.0
#   Downloading keras-layer-normalization-0.16.0.tar.gz (3.9 kB)
# Collecting keras-position-wise-feed-forward==0.8.0
#   Downloading keras-position-wise-feed-forward-0.8.0.tar.gz (4.1 kB)
# Collecting keras-embed-sim==0.10.0
#   Downloading keras-embed-sim-0.10.0.tar.gz (3.6 kB)
# Collecting keras-self-attention==0.51.0
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from matplotlib>=3.0.0->ktrain) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from matplotlib>=3.0.0->ktrain) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from matplotlib>=3.0.0->ktrain) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from matplotlib>=3.0.0->ktrain) (0.10.0)
# Requirement already satisfied: six in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.0.0->ktrain) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from pandas>=1.0.1->ktrain) (2021.3)
# Requirement already satisfied: idna<4,>=2.5 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from requests->ktrain) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from requests->ktrain) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from requests->ktrain) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from requests->ktrain) (2.0.4)
# Requirement already satisfied: click in /software-msca/ivy2/env/2021.05/ML2/lib/python3.9/site-packages (from sacremoses->transformers==4.10.3->ktrain) (8.0.1)
# Building wheels for collected packages: ktrain, keras-bert, keras-transformer, keras-embed-sim, keras-layer-normalization, keras-multi-head, keras-pos-embd, keras-position-wise-feed-forward, keras-self-attention, jieba, langdetect
#   Building wheel for ktrain (setup.py) ... done
#   Created wheel for ktrain: filename=ktrain-0.31.2-py3-none-any.whl size=25313065 sha256=1b9352385134155075d041bcbdde0e31305f6f98d2b3da171a31221b75e53642
#   Stored in directory: /home/vritti/.cache/pip/wheels/bc/ff/44/cb36ac7fcc8f510802d14ea191a45ca906ec50cdf7e8776064
#   Building wheel for keras-bert (setup.py) ... done
#   Created wheel for keras-bert: filename=keras_bert-0.89.0-py3-none-any.whl size=33516 sha256=e772eff860d1de8bcc1366a861bc93f1f2ba83fce3b7f8b322ef9d628afa907b
#   Stored in directory: /home/vritti/.cache/pip/wheels/4e/26/24/14ecbc0166364db7f5500164b7d796263cf3cd10c57e892180
#   Building wheel for keras-transformer (setup.py) ... done
#   Created wheel for keras-transformer: filename=keras_transformer-0.40.0-py3-none-any.whl size=12305 sha256=11faadbd6ce5fb5404e35d026d42712ce43b270d49c4a27832ed30bfbb2440b5
#   Stored in directory: /home/vritti/.cache/pip/wheels/5e/d6/d1/c588c3b2b112c8f1173934995836ab2f2de8323cce99fa998f
#   Building wheel for keras-embed-sim (setup.py) ... done
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.10.0-py3-none-any.whl size=3958 sha256=367f55a7360cf5dd3f8dbc3c64bc8f73667034b83e81cab0a10e2bf58ace4b1e
#   Stored in directory: /home/vritti/.cache/pip/wheels/cb/25/02/4bb438785ef9c10d07f6b3519f080b38917153fdac3108d738
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.16.0-py3-none-any.whl size=4668 sha256=97f279ae1805c539ad7282c901fd8da83d31d1c98d8b65e32428235bcc3226df
#   Stored in directory: /home/vritti/.cache/pip/wheels/c1/df/15/a88cdf68ce687574649f65063a743123e1bee79932b6eea3b6
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14993 sha256=ea4313fc1796c2a15df9285dc6ab7fc377685fa37658ef8a65632d857fb7458f
#   Stored in directory: /home/vritti/.cache/pip/wheels/b3/85/50/f232cac81ed1eb4dc20db31a9d1f4a8a1a8c696d4d27bff442
#   Building wheel for keras-pos-embd (setup.py) ... done
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.13.0-py3-none-any.whl size=6961 sha256=0ac7a7e90cef91d7168a046f7dd847f3c2224daae8cdea701e79b4e8d66a317a
#   Stored in directory: /home/vritti/.cache/pip/wheels/f5/8c/9a/917bf72d493e084ca1706a02679185789c2715f50770d8c987
#   Building wheel for keras-position-wise-feed-forward (setup.py) ... done
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.8.0-py3-none-any.whl size=4982 sha256=d3603644a80354d5d8ecb11e3f46709d330417a0d4bcd9eb61060a7e50367482
#   Stored in directory: /home/vritti/.cache/pip/wheels/20/36/25/efb605ab1742a179274a6f7cb113da1c6758f45e212b59bb4d
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18913 sha256=4fb711b68a0db096c692035f98e387f3132563593dce7adb1a988cf180790e49
#   Stored in directory: /home/vritti/.cache/pip/wheels/78/c1/84/b83a2fd6f1d63e136cba74bac4126bee3b8705eef6486635fd
#   Building wheel for jieba (setup.py) ... done
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314476 sha256=c58189eacd1aba2ed596b14512fdb04e1ce869f5479d8f8dfc85aa24fd8203bc
#   Stored in directory: /home/vritti/.cache/pip/wheels/7d/74/cf/08c94db4b784e2c1ef675a600b7b5b281fd25240dcb954ee7e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=d2ca2c41fb9e064c48b890c1fb7f4d50def20bbec0972e89a380e42d0570ead3
#   Stored in directory: /home/vritti/.cache/pip/wheels/d1/c1/d9/7e068de779d863bc8f8fc9467d85e25cfe47fa5051fff1a1bb
# Successfully built ktrain keras-bert keras-transformer keras-embed-sim keras-layer-normalization keras-multi-head keras-pos-embd keras-position-wise-feed-forward keras-self-attention jieba langdetect
# Installing collected packages: keras-self-attention, keras-position-wise-feed-forward, keras-pos-embd, keras-multi-head, keras-layer-normalization, keras-embed-sim, keras-transformer, whoosh, transformers, syntok, sentencepiece, langdetect, keras-bert, jieba, fastprogress, chardet, cchardet, ktrain
# Successfully installed cchardet-2.1.7 chardet-4.0.0 fastprogress-1.0.2 jieba-0.42.1 keras-bert-0.89.0 keras-embed-sim-0.10.0 keras-layer-normalization-0.16.0 keras-multi-head-0.29.0 keras-pos-embd-0.13.0 keras-position-wise-feed-forward-0.8.0 keras-self-attention-0.51.0 keras-transformer-0.40.0 ktrain-0.31.2 langdetect-1.0.9 sentencepiece-0.1.96 syntok-1.3.3 transformers-4.10.3 whoosh-2.7.4

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import re
import string
import ktrain

# %%
pd.set_option('display.max_colwidth', 500)

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Initializing the zero shot classifier

zsl = ktrain.text.ZeroShotClassifier()

# %%
df_cleaned_news = pd.read_csv('df_cleaned_news.csv')
df_cleaned_news.head()
# Out:
#    Unnamed: 0        date  \
# 0           0  2022-01-06
# 1           1  2022-01-06
# 2           2  2022-01-06
# 3           3  2022-01-06
# 4           4  2022-01-06
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             clean_text  \
# 0  chicago  ap   chicago school leaders canceled classes thursday   second consecutive day  failing  reach agreement   teachers union  covid   safety protocols   nation third largest school district  the chicago teachers union sought  revert  remote instruction   latest surge  infections    sides hammer   deal  but chicago public schools leaders  said remote learning  work  schools  safely remain open  protocols  place  the move  cancel classes  activities thursday affects roughly     students ...
# 1                                                                                                                                                                                                                                                       chicago pd    lies season   episode   promo  voight employs  new informant  help solve  tricky drug trafficking case  atwater     struggles  reconcile  personal  professional life  reaches  decision   jesseleesoffer  marinasqu  trspiridakos  nbcchicagopd
# 2  wise  foolish  the chicago tribune article titled  chicago public schools cancels classes  thursday  deadlock  union continues  trump  biden press secretary  comment  impasse  reported trumps solution  follows educate  children  person  give every dollar spent  education directly   students    get    failing government schools  trump said   statement  the purpose  this post is  relate  ancient wisdom proverb  trump solution  king solomon go   presence   foolish man   thou perceivest     lips...
# 3  the neighbors near mashawn plummer portage park firehouse knew    often sat outside   friendly presence   station  he showed  early   shifts  ready    job   thrilled    friends  family recalled  chicago firefighter emt mashawn plummer  engine     chicago fire department  hundreds  chicago firefighters joined family  friends  thursday  lay plummer  rest   died  december battling  apartment fire   northwest side  they remembered plummer       gentle giant  followed  dream  becoming  chicago fi...
# 4              mashawn plummer died final month  preventing  fireplace  town northwest aspect  additionally killed  civilian  a visitation  held  plummer wednesday night time  a remaining visitation  probably  held        home  hope church    e  114th st  related   chicago firefighter amongst   critically injured  belmont central residence fireplace    killed following  ultimate visitation  funeral companies  start         probably  adopted   procession  oak woods cemetery  67th road  the   yea...
#
#                                                                                                                     clean_title
# 0                                                                           no deal   school  chicago cancels classes   2nd day
# 1                                                                                          watch chicago p d  preview wednesday
# 2                                                                     trump solution  chicago public schools  king solomon blog
# 3  family  friends  colleagues gathering today  south side church  attend funeral services  chicago firefighter mashawn plummer
# 4                                                     chicago firefighter funeral  pals  household say goodbye  mashawn plummer

# %%
df_cleaned_news.isna().sum()
# Out:
# Unnamed: 0     0
# date           0
# clean_text     7
# clean_title    6
# dtype: int64

# %%
df_cleaned_news.dropna(inplace=True)

# %%
df_cleaned_news.shape
# Out:
# (165360, 4)

# %%
df_cleaned_news.reset_index(inplace=True, drop=True)

# %%
df_cleaned_news.shape
# Out:
# (165360, 4)

# %%
texts = df_cleaned_news['clean_text'].tolist()

# %%
texts[0]
# Out:
# 'chicago  ap   chicago school leaders canceled classes thursday   second consecutive day  failing  reach agreement   teachers union  covid   safety protocols   nation third largest school district  the chicago teachers union sought  revert  remote instruction   latest surge  infections    sides hammer   deal  but chicago public schools leaders  said remote learning  work  schools  safely remain open  protocols  place  the move  cancel classes  activities thursday affects roughly     students  came  closed door negotiations wednesday failed  produce  deal  the issues include metrics  closing schools  we   choice   cancel classes tomorrow  schools ceo pedro martinez said   wednesday evening news conference  students returned  class monday   two week winter break  covid   infections  hospitalizations fueled   omicron variant  record levels  school districts nationwide  grappled    issue     opting  stay open  ramping  virus testing  tweaking protocols   adjustments  response   shifting pandemic  white house press secretary jen psaki  echoing president joe biden  day earlier   said wednesday   country  better equipped   make sure schools  safely open including  chicago   former president donald trump called  closures devastating  chicago teachers union president jesse sharkey said teachers  want  return   person instruction   current surge  subsided  we rather    classes teaching   rather   schools open  what   saying though   right     middle   major surge    breaking   records  hospitals  full   said   wednesday morning news conference   union officials  teachers  parents  the union action  approved      members  called  remote instruction  cases substantially subside  union leaders approve  agreement  safety protocols   district  the district said early tuesday  classes would  canceled wednesday   union voted   return   person instruction  devices   distributed  students ahead   union vote    announced     p   tuesday  union members  tried  log  teaching systems wednesday said   locked   district officials blamed  union   late cancellation  saying despite safety measures including  high teacher vaccination rate   teachers   willing  report  work  we  deeply concerned   decision  even  concerned   impact   health  safety   well    students  families   district said   statement  cps leaders said  plan would come later wednesday  continue student learning   district   students  largely low income  black  latino  school officials labeled  union action  illegal work stoppage  said     report  schools wednesday would   compensated  last year   similar debate   district punished teachers    come  schools   keyonna payton   teacher  park manor elementary school  also chairs  safety committee  said  taught remotely monday  tuesday     students   home  quarantine  payton said   vaccinated  boosted      child  attends classes   district   also vaccinated     fearful   variant spreading   family  including    year old grandmother  i   part  try  protect  children  however  i  afraid   virus  variant    fast   moving  spreading   said   wednesday news conference  danelda craig   parent  also spoke   news conference  said   taken aback   suggestion   city public health commissioner  people could wear two masks  improve protection  craig said  children struggle  one  we want   go  school   said  what   want  covid    in illinois  masks  required  indoor settings  including schools  while  significantly smaller  neighboring school districts  returned  plan  return  class  week  others  temporarily returned  remote learning  niles township high school district    skokie   north  chicago  switched  remote learning   first two weeks  january due  staffing shortages    lincoln way district southwest  chicago    one week  also due  staffing  in chicago   district proposed guidelines  individual school closures  saying safety measures like required masks  availability  vaccines  improved ventilation make schools among  safest places  kids    roughly ...

# %%
# Sample prediction with ZSL

labels=['positive', 'negative']
zsl.predict(texts[0], labels=labels, include_labels=False, nli_template="The sentiment of this article is {}.", multilabel=False)
# Out:
# [0.5120956301689148, 0.4879043400287628]

# %%
# Prediction positive/negative sentiments with ZSL

predictions = [zsl.predict(text, labels=labels, include_labels=False, \
                           nli_template="The sentiment of this news article is {}.") for text in texts]

# %%
predictions_df = pd.DataFrame(predictions, columns=[labels])

# %%
predictions_df.head()
# Out:
#    positive  negative
# 0  0.295749  0.957052
# 1  0.002615  0.986636
# 2  0.040025  0.966754
# 3  0.892183  0.033660
# 4  0.915046  0.068743

# %%
news_sentiments = df_cleaned_news.join(predictions_df, how='inner')

# %%
news_sentiments.head()
# Out:
#    Unnamed: 0        date  \
# 0           0  2022-01-06
# 1           1  2022-01-06
# 2           2  2022-01-06
# 3           3  2022-01-06
# 4           4  2022-01-06
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             clean_text  \
# 0  chicago  ap   chicago school leaders canceled classes thursday   second consecutive day  failing  reach agreement   teachers union  covid   safety protocols   nation third largest school district  the chicago teachers union sought  revert  remote instruction   latest surge  infections    sides hammer   deal  but chicago public schools leaders  said remote learning  work  schools  safely remain open  protocols  place  the move  cancel classes  activities thursday affects roughly     students ...
# 1                                                                                                                                                                                                                                                       chicago pd    lies season   episode   promo  voight employs  new informant  help solve  tricky drug trafficking case  atwater     struggles  reconcile  personal  professional life  reaches  decision   jesseleesoffer  marinasqu  trspiridakos  nbcchicagopd
# 2  wise  foolish  the chicago tribune article titled  chicago public schools cancels classes  thursday  deadlock  union continues  trump  biden press secretary  comment  impasse  reported trumps solution  follows educate  children  person  give every dollar spent  education directly   students    get    failing government schools  trump said   statement  the purpose  this post is  relate  ancient wisdom proverb  trump solution  king solomon go   presence   foolish man   thou perceivest     lips...
# 3  the neighbors near mashawn plummer portage park firehouse knew    often sat outside   friendly presence   station  he showed  early   shifts  ready    job   thrilled    friends  family recalled  chicago firefighter emt mashawn plummer  engine     chicago fire department  hundreds  chicago firefighters joined family  friends  thursday  lay plummer  rest   died  december battling  apartment fire   northwest side  they remembered plummer       gentle giant  followed  dream  becoming  chicago fi...
# 4              mashawn plummer died final month  preventing  fireplace  town northwest aspect  additionally killed  civilian  a visitation  held  plummer wednesday night time  a remaining visitation  probably  held        home  hope church    e  114th st  related   chicago firefighter amongst   critically injured  belmont central residence fireplace    killed following  ultimate visitation  funeral companies  start         probably  adopted   procession  oak woods cemetery  67th road  the   yea...
#
#                                                                                                                     clean_title  \
# 0                                                                           no deal   school  chicago cancels classes   2nd day
# 1                                                                                          watch chicago p d  preview wednesday
# 2                                                                     trump solution  chicago public schools  king solomon blog
# 3  family  friends  colleagues gathering today  south side church  attend funeral services  chicago firefighter mashawn plummer
# 4                                                     chicago firefighter funeral  pals  household say goodbye  mashawn plummer
#
#    (positive,)  (negative,)
# 0     0.295749     0.957052
# 1     0.002615     0.986636
# 2     0.040025     0.966754
# 3     0.892183     0.033660
# 4     0.915046     0.068743

# %%
news_sentiments = news_sentiments.rename(columns={news_sentiments.columns[4]: "positive", \
                                                  news_sentiments.columns[5]: "negative"})

# %%
news_sentiments.to_csv("zero_shot_sentiments.csv")

# %%
news_sentiments.shape
# Out:
# (165360, 6)

# %%
news_sentiments.head()
# Out:
#    Unnamed: 0        date  \
# 0           0  2022-01-06
# 1           1  2022-01-06
# 2           2  2022-01-06
# 3           3  2022-01-06
# 4           4  2022-01-06
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             clean_text  \
# 0  chicago  ap   chicago school leaders canceled classes thursday   second consecutive day  failing  reach agreement   teachers union  covid   safety protocols   nation third largest school district  the chicago teachers union sought  revert  remote instruction   latest surge  infections    sides hammer   deal  but chicago public schools leaders  said remote learning  work  schools  safely remain open  protocols  place  the move  cancel classes  activities thursday affects roughly     students ...
# 1                                                                                                                                                                                                                                                       chicago pd    lies season   episode   promo  voight employs  new informant  help solve  tricky drug trafficking case  atwater     struggles  reconcile  personal  professional life  reaches  decision   jesseleesoffer  marinasqu  trspiridakos  nbcchicagopd
# 2  wise  foolish  the chicago tribune article titled  chicago public schools cancels classes  thursday  deadlock  union continues  trump  biden press secretary  comment  impasse  reported trumps solution  follows educate  children  person  give every dollar spent  education directly   students    get    failing government schools  trump said   statement  the purpose  this post is  relate  ancient wisdom proverb  trump solution  king solomon go   presence   foolish man   thou perceivest     lips...
# 3  the neighbors near mashawn plummer portage park firehouse knew    often sat outside   friendly presence   station  he showed  early   shifts  ready    job   thrilled    friends  family recalled  chicago firefighter emt mashawn plummer  engine     chicago fire department  hundreds  chicago firefighters joined family  friends  thursday  lay plummer  rest   died  december battling  apartment fire   northwest side  they remembered plummer       gentle giant  followed  dream  becoming  chicago fi...
# 4              mashawn plummer died final month  preventing  fireplace  town northwest aspect  additionally killed  civilian  a visitation  held  plummer wednesday night time  a remaining visitation  probably  held        home  hope church    e  114th st  related   chicago firefighter amongst   critically injured  belmont central residence fireplace    killed following  ultimate visitation  funeral companies  start         probably  adopted   procession  oak woods cemetery  67th road  the   yea...
#
#                                                                                                                     clean_title  \
# 0                                                                           no deal   school  chicago cancels classes   2nd day
# 1                                                                                          watch chicago p d  preview wednesday
# 2                                                                     trump solution  chicago public schools  king solomon blog
# 3  family  friends  colleagues gathering today  south side church  attend funeral services  chicago firefighter mashawn plummer
# 4                                                     chicago firefighter funeral  pals  household say goodbye  mashawn plummer
#
#    positive  negative
# 0  0.295749  0.957052
# 1  0.002615  0.986636
# 2  0.040025  0.966754
# 3  0.892183  0.033660
# 4  0.915046  0.068743
